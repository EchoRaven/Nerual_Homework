# %%
import os
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.utils.data as Data
import torchvision
import torch.nn.functional as F
import numpy as np

learning_rate = 1e-4
keep_prob_rate = 0.7
max_epoch = 3
BATCH_SIZE = 50

DOWNLOAD_MNIST = False
if not(os.path.exists('./mnist/')) or not os.listdir('./mnist/'):
    DOWNLOAD_MNIST = True

train_data = torchvision.datasets.MNIST(root='./mnist/', train=True, transform=torchvision.transforms.ToTensor(), download=DOWNLOAD_MNIST)
train_loader = Data.DataLoader(dataset=train_data, batch_size=BATCH_SIZE, shuffle=True)

test_data = torchvision.datasets.MNIST(root='./mnist/', train=False, transform=torchvision.transforms.ToTensor())
test_x = Variable(torch.unsqueeze(test_data.data, dim=1), volatile=True).type(torch.FloatTensor)[:500] / 255.
test_y = test_data.targets[:500].numpy()

class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d(
                in_channels=1,
                out_channels=32,
                kernel_size=5,
                stride=1,
                padding=2,
            ),
            nn.ReLU(),
            nn.MaxPool2d(2),
        )
        self.conv2 = nn.Sequential(
            nn.Conv2d(
                in_channels=32,
                out_channels=64,
                kernel_size=5,
                stride=1,
                padding=2,
            ),
            nn.ReLU(),
            nn.MaxPool2d(2),
        )
        self.out1 = nn.Linear(64 * 7 * 7, 1024, bias=True)
        self.dropout = nn.Dropout(keep_prob_rate)
        self.out2 = nn.Linear(1024, 10, bias=True)

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = x.view(x.size(0), -1)  # flatten the output of conv2
        out1 = self.out1(x)
        out1 = F.relu(out1)
        out1 = self.dropout(out1)
        out2 = self.out2(out1)
        output = F.softmax(out2, dim=1)
        return output

def test(cnn):
    y_pre = cnn(test_x)
    _, pre_index = torch.max(y_pre, 1)
    pre_index = pre_index.view(-1)
    prediction = pre_index.data.numpy()
    correct = np.sum(prediction == test_y)
    return correct / 500.0

def train(cnn):
    optimizer = torch.optim.Adam(cnn.parameters(), lr=learning_rate)
    loss_func = nn.CrossEntropyLoss()
    for epoch in range(max_epoch):
        for step, (x_, y_) in enumerate(train_loader):
            x, y = Variable(x_), Variable(y_)
            output = cnn(x)
            loss = loss_func(output, y)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            if step != 0 and step % 20 == 0:
                print("=" * 10, step, "=" * 5, "=" * 5, "test accuracy is ", test(cnn), "=" * 10)

if __name__ == '__main__':
    cnn = CNN()
    train(cnn)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./mnist/MNIST\raw\train-images-idx3-ubyte.gz
# 100.0%
# Extracting ./mnist/MNIST\raw\train-images-idx3-ubyte.gz to ./mnist/MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./mnist/MNIST\raw\train-labels-idx1-ubyte.gz
# 100.0%
# Extracting ./mnist/MNIST\raw\train-labels-idx1-ubyte.gz to ./mnist/MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./mnist/MNIST\raw\t10k-images-idx3-ubyte.gz
# 100.0%
# Extracting ./mnist/MNIST\raw\t10k-images-idx3-ubyte.gz to ./mnist/MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./mnist/MNIST\raw\t10k-labels-idx1-ubyte.gz
# 100.0%
# C:\Users\thb20\AppData\Local\Temp\ipykernel_37396\4278845010.py:23: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   test_x = Variable(torch.unsqueeze(test_data.data, dim=1), volatile=True).type(torch.FloatTensor)[:500] / 255.
# Extracting ./mnist/MNIST\raw\t10k-labels-idx1-ubyte.gz to ./mnist/MNIST\raw
#
# ========== 20 ===== ===== test accuracy is  0.23 ==========
# ========== 40 ===== ===== test accuracy is  0.292 ==========
# ========== 60 ===== ===== test accuracy is  0.448 ==========
# ========== 80 ===== ===== test accuracy is  0.56 ==========
# ========== 100 ===== ===== test accuracy is  0.596 ==========
# ========== 120 ===== ===== test accuracy is  0.62 ==========
# ========== 140 ===== ===== test accuracy is  0.674 ==========
# ========== 160 ===== ===== test accuracy is  0.688 ==========
# ========== 180 ===== ===== test accuracy is  0.736 ==========
# ========== 200 ===== ===== test accuracy is  0.77 ==========
# ========== 220 ===== ===== test accuracy is  0.798 ==========
# ========== 240 ===== ===== test accuracy is  0.81 ==========
# ========== 260 ===== ===== test accuracy is  0.836 ==========
# ========== 280 ===== ===== test accuracy is  0.834 ==========
# ========== 300 ===== ===== test accuracy is  0.856 ==========
# ========== 320 ===== ===== test accuracy is  0.866 ==========
# ========== 340 ===== ===== test accuracy is  0.874 ==========
# ========== 360 ===== ===== test accuracy is  0.87 ==========
# ========== 380 ===== ===== test accuracy is  0.882 ==========
# ========== 400 ===== ===== test accuracy is  0.904 ==========
# ========== 420 ===== ===== test accuracy is  0.888 ==========
# ========== 440 ===== ===== test accuracy is  0.892 ==========
# ========== 460 ===== ===== test accuracy is  0.88 ==========
# ========== 480 ===== ===== test accuracy is  0.898 ==========
# ========== 500 ===== ===== test accuracy is  0.902 ==========
# ========== 520 ===== ===== test accuracy is  0.912 ==========
# ========== 540 ===== ===== test accuracy is  0.904 ==========
# ========== 560 ===== ===== test accuracy is  0.91 ==========
# ========== 580 ===== ===== test accuracy is  0.924 ==========
# ========== 600 ===== ===== test accuracy is  0.906 ==========
# ========== 620 ===== ===== test accuracy is  0.928 ==========
# ========== 640 ===== ===== test accuracy is  0.938 ==========
# ========== 660 ===== ===== test accuracy is  0.93 ==========
# ========== 680 ===== ===== test accuracy is  0.93 ==========
# ========== 700 ===== ===== test accuracy is  0.926 ==========
# ========== 720 ===== ===== test accuracy is  0.938 ==========
# ========== 740 ===== ===== test accuracy is  0.928 ==========
# ========== 760 ===== ===== test accuracy is  0.94 ==========
# ========== 780 ===== ===== test accuracy is  0.92 ==========
# ========== 800 ===== ===== test accuracy is  0.94 ==========
# ========== 820 ===== ===== test accuracy is  0.938 ==========
# ========== 840 ===== ===== test accuracy is  0.938 ==========
# ========== 860 ===== ===== test accuracy is  0.942 ==========
# ========== 880 ===== ===== test accuracy is  0.942 ==========
# ========== 900 ===== ===== test accuracy is  0.93 ==========
# ========== 920 ===== ===== test accuracy is  0.936 ==========
# ========== 940 ===== ===== test accuracy is  0.942 ==========
# ========== 960 ===== ===== test accuracy is  0.93 ==========
# ========== 980 ===== ===== test accuracy is  0.954 ==========
# ========== 1000 ===== ===== test accuracy is  0.95 ==========
# ========== 1020 ===== ===== test accuracy is  0.948 ==========
# ========== 1040 ===== ===== test accuracy is  0.952 ==========
# ========== 1060 ===== ===== test accuracy is  0.946 ==========
# ========== 1080 ===== ===== test accuracy is  0.94 ==========
# ========== 1100 ===== ===== test accuracy is  0.95 ==========
# ========== 1120 ===== ===== test accuracy is  0.966 ==========
# ========== 1140 ===== ===== test accuracy is  0.944 ==========
# ========== 1160 ===== ===== test accuracy is  0.948 ==========
# ========== 1180 ===== ===== test accuracy is  0.934 ==========
# ========== 20 ===== ===== test accuracy is  0.958 ==========
# ========== 40 ===== ===== test accuracy is  0.952 ==========
# ========== 60 ===== ===== test accuracy is  0.954 ==========
# ========== 80 ===== ===== test accuracy is  0.954 ==========
# ========== 100 ===== ===== test accuracy is  0.954 ==========
# ========== 120 ===== ===== test accuracy is  0.962 ==========
# ========== 140 ===== ===== test accuracy is  0.958 ==========
# ========== 160 ===== ===== test accuracy is  0.952 ==========
# ========== 180 ===== ===== test accuracy is  0.954 ==========
# ========== 200 ===== ===== test accuracy is  0.964 ==========
# ========== 220 ===== ===== test accuracy is  0.958 ==========
# ========== 240 ===== ===== test accuracy is  0.952 ==========
# ========== 260 ===== ===== test accuracy is  0.952 ==========
# ========== 280 ===== ===== test accuracy is  0.96 ==========
# ========== 300 ===== ===== test accuracy is  0.96 ==========
# ========== 320 ===== ===== test accuracy is  0.972 ==========
# ========== 340 ===== ===== test accuracy is  0.95 ==========
# ========== 360 ===== ===== test accuracy is  0.954 ==========
# ========== 380 ===== ===== test accuracy is  0.948 ==========
# ========== 400 ===== ===== test accuracy is  0.966 ==========
# ========== 420 ===== ===== test accuracy is  0.96 ==========
# ========== 440 ===== ===== test accuracy is  0.96 ==========
# ========== 460 ===== ===== test accuracy is  0.954 ==========
# ========== 480 ===== ===== test accuracy is  0.954 ==========
# ========== 500 ===== ===== test accuracy is  0.96 ==========
# ========== 520 ===== ===== test accuracy is  0.96 ==========
# ========== 540 ===== ===== test accuracy is  0.964 ==========
# ========== 560 ===== ===== test accuracy is  0.974 ==========
# ========== 580 ===== ===== test accuracy is  0.968 ==========
# ========== 600 ===== ===== test accuracy is  0.97 ==========
# ========== 620 ===== ===== test accuracy is  0.97 ==========
# ========== 640 ===== ===== test accuracy is  0.958 ==========
# ========== 660 ===== ===== test accuracy is  0.954 ==========
# ========== 680 ===== ===== test accuracy is  0.974 ==========
# ========== 700 ===== ===== test accuracy is  0.958 ==========
# ========== 720 ===== ===== test accuracy is  0.964 ==========
# ========== 740 ===== ===== test accuracy is  0.966 ==========
# ========== 760 ===== ===== test accuracy is  0.968 ==========
# ========== 780 ===== ===== test accuracy is  0.962 ==========
# ========== 800 ===== ===== test accuracy is  0.966 ==========
# ========== 820 ===== ===== test accuracy is  0.956 ==========
# ========== 840 ===== ===== test accuracy is  0.968 ==========
# ========== 860 ===== ===== test accuracy is  0.968 ==========
# ========== 880 ===== ===== test accuracy is  0.966 ==========
# ========== 900 ===== ===== test accuracy is  0.962 ==========
# ========== 920 ===== ===== test accuracy is  0.972 ==========
# ========== 940 ===== ===== test accuracy is  0.958 ==========
# ========== 960 ===== ===== test accuracy is  0.964 ==========
# ========== 980 ===== ===== test accuracy is  0.96 ==========
# ========== 1000 ===== ===== test accuracy is  0.98 ==========
# ========== 1020 ===== ===== test accuracy is  0.956 ==========
# ========== 1040 ===== ===== test accuracy is  0.966 ==========
# ========== 1060 ===== ===== test accuracy is  0.968 ==========
# ========== 1080 ===== ===== test accuracy is  0.974 ==========
# ========== 1100 ===== ===== test accuracy is  0.978 ==========
# ========== 1120 ===== ===== test accuracy is  0.97 ==========
# ========== 1140 ===== ===== test accuracy is  0.968 ==========
# ========== 1160 ===== ===== test accuracy is  0.976 ==========
# ========== 1180 ===== ===== test accuracy is  0.976 ==========
# ========== 20 ===== ===== test accuracy is  0.968 ==========
# ========== 40 ===== ===== test accuracy is  0.978 ==========
# ========== 60 ===== ===== test accuracy is  0.976 ==========
# ========== 80 ===== ===== test accuracy is  0.962 ==========
# ========== 100 ===== ===== test accuracy is  0.962 ==========
# ========== 120 ===== ===== test accuracy is  0.976 ==========
# ========== 140 ===== ===== test accuracy is  0.974 ==========
# ========== 160 ===== ===== test accuracy is  0.968 ==========
# ========== 180 ===== ===== test accuracy is  0.976 ==========
# ========== 200 ===== ===== test accuracy is  0.964 ==========
# ========== 220 ===== ===== test accuracy is  0.972 ==========
# ========== 240 ===== ===== test accuracy is  0.97 ==========
# ========== 260 ===== ===== test accuracy is  0.968 ==========
# ========== 280 ===== ===== test accuracy is  0.96 ==========
# ========== 300 ===== ===== test accuracy is  0.966 ==========
# ========== 320 ===== ===== test accuracy is  0.968 ==========
# ========== 340 ===== ===== test accuracy is  0.966 ==========
# ========== 360 ===== ===== test accuracy is  0.966 ==========
# ========== 380 ===== ===== test accuracy is  0.982 ==========
# ========== 400 ===== ===== test accuracy is  0.96 ==========
# ========== 420 ===== ===== test accuracy is  0.974 ==========
# ========== 440 ===== ===== test accuracy is  0.97 ==========
# ========== 460 ===== ===== test accuracy is  0.968 ==========
# ========== 480 ===== ===== test accuracy is  0.978 ==========
# ========== 500 ===== ===== test accuracy is  0.98 ==========
# ========== 520 ===== ===== test accuracy is  0.974 ==========
# ========== 540 ===== ===== test accuracy is  0.974 ==========
# ========== 560 ===== ===== test accuracy is  0.97 ==========
# ========== 580 ===== ===== test accuracy is  0.972 ==========
# ========== 600 ===== ===== test accuracy is  0.974 ==========
# ========== 620 ===== ===== test accuracy is  0.976 ==========
# ========== 640 ===== ===== test accuracy is  0.98 ==========
# ========== 660 ===== ===== test accuracy is  0.97 ==========
# ========== 680 ===== ===== test accuracy is  0.966 ==========
# ========== 700 ===== ===== test accuracy is  0.97 ==========
# ========== 720 ===== ===== test accuracy is  0.978 ==========
# ========== 740 ===== ===== test accuracy is  0.968 ==========
# ========== 760 ===== ===== test accuracy is  0.972 ==========
# ========== 780 ===== ===== test accuracy is  0.968 ==========
# ========== 800 ===== ===== test accuracy is  0.98 ==========
# ========== 820 ===== ===== test accuracy is  0.97 ==========
# ========== 840 ===== ===== test accuracy is  0.97 ==========
# ========== 860 ===== ===== test accuracy is  0.968 ==========
# ========== 880 ===== ===== test accuracy is  0.974 ==========
# ========== 900 ===== ===== test accuracy is  0.976 ==========
# ========== 920 ===== ===== test accuracy is  0.976 ==========
# ========== 940 ===== ===== test accuracy is  0.982 ==========
# ========== 960 ===== ===== test accuracy is  0.98 ==========
# ========== 980 ===== ===== test accuracy is  0.976 ==========
# ========== 1000 ===== ===== test accuracy is  0.97 ==========
# ========== 1020 ===== ===== test accuracy is  0.98 ==========
# ========== 1040 ===== ===== test accuracy is  0.968 ==========
# ========== 1060 ===== ===== test accuracy is  0.974 ==========
# ========== 1080 ===== ===== test accuracy is  0.964 ==========
# ========== 1100 ===== ===== test accuracy is  0.97 ==========
# ========== 1120 ===== ===== test accuracy is  0.974 ==========
# ========== 1140 ===== ===== test accuracy is  0.98 ==========
# ========== 1160 ===== ===== test accuracy is  0.98 ==========
# ========== 1180 ===== ===== test accuracy is  0.972 ==========
